# %%
from csromer.faraday_sky import FaradaySky
from astropy.io import fits
import matplotlib.pyplot as plt

# %%
f_sky = FaradaySky(filename="./../faradaysky/faraday2020v2.hdf5")

# %%
hdul = fits.open("/home/miguel/Documents/datasets/A1314_JVLA/mfs/A1314_I.fits")[0]

# %%
mean, std = f_sky.galactic_rm_image(hdul.header, use_bilinear_interpolation=True)

# %%
plt.imshow(mean)
plt.colorbar()
