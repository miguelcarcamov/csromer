# %%
from csromer.plots import Plotter
from astropy.io import fits
import matplotlib.pyplot as plt
import astropy.units as u

# %%
radio_image_name = "/home/miguel/Documents/datasets/A1314_JVLA/mfs/A1314_I.fits"
xray_image_name = "/home/miguel/Documents/galaxyclusters_FOF/A1314/xray.fits"

# %%
hdul_radio = fits.open(radio_image_name)[0]
hdul_xray = fits.open(xray_image_name)

# %%
plotter = Plotter(radio_image=hdul_radio, xray_image=hdul_xray, use_latex=True, z=0.034, scalebar_length_kpc=100*u.kpc)

# %%
plotter.get_optical(rgb=False)
# Out:
# WARNING: InputWarning: Coordinate string is being interpreted as an ICRS coordinate. [astroquery.utils.commons]

# %%
plt.imshow(plotter.optical_image.data, origin='lower')

# %%
plotter.get_additional(surveys="WISE 3.4")

# %%
plt.imshow(plotter.additional_image.data, origin='lower')

# %%
plt.imshow(plotter.radio_image.data.squeeze(), origin='lower')

# %%
plotter.plot_overlay(xlabel="Right Ascension [J2000]", ylabel='Declination [J2000]', sigma_list=[3.75, 50.0, 5.0], savefig=True)
# Out:
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -107.618000 from OBSGEO-[XYZ].
# Set OBSGEO-B to    34.078827 from OBSGEO-[XYZ].
# Set OBSGEO-H to     2115.607 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / Equatorial system reference
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: AstropyDeprecationWarning: The truth value of a Quantity is ambiguous. In the future this will raise a ValueError. [astropy.units.quantity]
