# %%
import copy
import itertools
import os
import time

import matplotlib.pyplot as plt
import numpy as np
import pywt
from IPython.display import clear_output
from pynufft import NUFFT
from scipy import signal as sci_signal
from scipy.constants import c

from csromer.base import Dataset
from csromer.dictionaries.discrete import DiscreteWavelet
from csromer.dictionaries.undecimated import UndecimatedWavelet
from csromer.io import Reader, Writer
from csromer.objectivefunction import L1, TSV, TV, Chi2, OFunction
from csromer.optimization import ADMM, FISTA, SDMM, GradientBasedMethod
from csromer.reconstruction import Parameter
from csromer.simulation import FaradayThickSource, FaradayThinSource
from csromer.transformers import DFT1D, NUFFT1D, Gridding
from csromer.utils import Gaussian, complex_to_real, real_to_complex

# %matplotlib inline

#np.random.seed(666)

# %%
def gini_coefficient(w):
    # Order vector
    w_ordered = np.sort(np.abs(w), kind="stable")
    l1_norm = np.sum(np.abs(w_ordered))
    M = len(w_ordered)
    m = np.arange(0, M)
    const = (M - m + 1.5) / M
    if l1_norm == 0.0:
        coeff = np.nan
    else:
        coeff = np.sum((w_ordered / l1_norm) * const)
    return 1.0 - 2.0 * coeff

# %%
def chi2_calc(residuals):
    if residuals.dtype == np.complex64 or residuals.dtype == np.complex128:
        data = residuals.real**2 + residuals.imag**2
    else:
        data = residuals**2
    return np.sum(data)

# %%
def aicbic(residuals, x):
    rss = chi2_calc(residuals)
    if x.dtype == np.complex64 or x.dtype == np.complex128:
        df = np.count_nonzero(x.real) + np.count_nonzero(x.imag)
    else:
        df = np.count_nonzero(x)
    l = 2 * len(residuals)
    return l * np.log(rss / l) + 2 * df, l * np.log(rss / l) + df * np.log(l)

# %%
def list_to2darray(x: list = None, cols: int = None, dtype=None):
    b = list(map(list, zip(*[iter(x)] * cols)))
    #b = [x[cols*i : cols*(i+1)] for i in range(rows)]
    if dtype is None:
        return np.array(b)
    else:
        return np.array(b, dtype=dtype)

# %%
class statistics:

    def __init__(self, m, n, z):
        self.sum = np.zeros((m, n), dtype=np.float32)
        self.sum2 = np.zeros((m, n), dtype=np.float32)
        self.n = z * np.ones((m, n), dtype=np.int32)

    def cumul(self, x):
        x_values = np.where(x != np.nan, x, 0.0)
        subtract = np.where(x == np.nan, -1, 0)
        self.sum += x_values
        self.sum2 += x_values * x_values
        self.n += subtract

    def mean(self):
        return np.where(self.n > 0, self.sum / self.n, np.nan)

    def std(self):
        return np.where(
            self.n > 0, np.sqrt(self.sum2 / self.n - self.sum * self.sum / self.n / self.n), np.nan
        )

# %%
class Test:

    def __init__(
        self,
        nu_min=None,
        nu_max=None,
        nchannels=None,
        noise_frac=None,
        remove_frac=None,
        use_gridding=False,
        ftransform="nufft",
        use_wavelet=None,
        source_1=None,
        source_2=None,
        scenario=1,
        append_signal=False
    ):
        self.nu_min = nu_min
        self.nu_max = nu_max
        self.nchannels = nchannels
        self.noise_frac = noise_frac
        self.remove_frac = remove_frac
        self.use_gridding = use_gridding
        self.use_wavelet = use_wavelet
        self.ftransform = ftransform
        self.scenario = scenario
        self.append_signal = append_signal
        self.nu = np.linspace(start=nu_min, stop=nu_max, num=nchannels)
        self.source_1 = copy.deepcopy(source_1)
        self.source_2 = copy.deepcopy(source_2)

        if self.source_1 is not None:
            self.source_1.nu = self.nu
            self.source_1.l2_ref = self.source_1.calculate_l2ref()
            self.source_1.simulate()

        if self.source_2 is not None:
            self.source_2.nu = self.nu
            self.source_2.l2_ref = self.source_2.calculate_l2ref()
            self.source_2.simulate()

        if scenario == 1:
            self.source = self.source_1
        elif scenario == 2:
            self.source = self.source_2
        elif scenario == 3:
            self.source = self.source_1 + self.source_2
        else:
            raise ValueError("This scenario does not exist")

        if remove_frac:
            self.source.remove_channels(remove_frac, np.random.RandomState(int(time.time())))

        self.noiseless_source = copy.deepcopy(self.source)

        if scenario == 1:
            self.avg_signal = np.abs(self.source_1.s_nu)
        elif scenario == 2:
            self.avg_signal = np.abs(self.source_2.s_nu)
        else:
            self.avg_signal = (np.abs(self.source_1.s_nu) + np.abs(self.source_2.s_nu)) / 2.0

        if noise_frac:
            self.source.apply_noise(self.avg_signal * self.noise_frac)

        if use_gridding:
            gridding = Gridding(self.source)
            gridding_noiseless = Gridding(self.noiseless_source)
            self.source = gridding.run()
            self.noiseless_source = gridding_noiseless.run()

    def apply_noise(self):
        if self.noise_frac:
            self.source.apply_noise(
                self.avg_signal * self.noise_frac, np.random.RandomState(int(time.time()))
            )

    def run(self, lambda_tv: float = None, lambda_tsv: float = None):
        self.parameter = Parameter()
        self.parameter.calculate_cellsize(dataset=self.source)

        dft = DFT1D(dataset=self.source, parameter=self.parameter)

        self.F_dirty = dft.backward(self.source.data)

        if self.use_wavelet:
            self.wavelet = DiscreteWavelet(
                wavelet_name=self.use_wavelet,
                mode="periodization",
                append_signal=self.append_signal
            )
            #self.wavelet = UndecimatedWavelet(wavelet_name=self.use_wavelet, mode="periodization", append_signal=self.append_signal)
            self.lambda_l1 = np.sqrt(len(self.source.data) + 2 * np.sqrt(len(self.source.data))
                                     ) * 2.0 * np.sqrt(2) * np.mean(self.source.sigma)
        else:
            self.lambda_l1 = np.sqrt(len(self.source.data) + 2 * np.sqrt(len(self.source.data))
                                     ) * np.sqrt(2) * np.mean(self.source.sigma)

        if lambda_tv is None:
            lambda_tv = 0.0

        if lambda_tsv is None:
            lambda_tsv = 0.0

        if self.ftransform == "nufft":
            nufft = NUFFT1D(dataset=self.source, parameter=self.parameter, solve=True)
            if self.use_wavelet:
                chi2 = Chi2(dft_obj=nufft, wavelet=self.wavelet)
            else:
                chi2 = Chi2(dft_obj=nufft)
        else:
            if self.use_wavelet:
                chi2 = Chi2(dft_obj=dft, wavelet=self.wavelet)
            else:
                chi2 = Chi2(dft_obj=dft)

        l1 = L1(reg=self.lambda_l1)
        tsv = TSV(reg=lambda_tsv)
        tv = TV(reg=lambda_tv)
        F_func = [chi2, l1, tsv]
        f_func = [chi2]
        g_func = [l1, tsv]

        F_obj = OFunction(F_func)
        f_obj = OFunction(f_func)
        g_obj = OFunction(g_func)

        self.parameter.data = self.F_dirty

        self.parameter.complex_data_to_real()

        if self.use_wavelet:
            self.parameter.data = self.wavelet.decompose(self.parameter.data)
            opt = FISTA(
                guess_param=self.parameter,
                F_obj=F_obj,
                fx=chi2,
                gx=g_obj,
                noise=2.0 * self.source.theo_noise,
                verbose=False
            )
        else:
            opt = FISTA(
                guess_param=self.parameter,
                F_obj=F_obj,
                fx=chi2,
                gx=g_obj,
                noise=self.source.theo_noise,
                verbose=False
            )

        self.obj, self.X = opt.run()

        if self.use_wavelet is not None:
            self.coeffs = copy.deepcopy(self.X.data)
            k = np.count_nonzero(self.coeffs)
            self.sparsity = k / len(self.coeffs)
            self.gini = gini_coefficient(self.coeffs)
            self.X.data = self.wavelet.reconstruct(self.X.data)
            self.aic, self.bic = aicbic(self.source.residual, self.coeffs)

        else:
            k = np.count_nonzero(self.X.data)
            self.sparsity = k / len(self.X.data)
            self.gini = gini_coefficient(self.X.data)
            self.aic, self.bic = aicbic(self.source.residual, self.X.data)

        self.X.real_data_to_complex()

        self.X_residual = dft.backward(self.source.residual)

        self.X_restored = self.X.convolve() + self.X_residual

        self.res_noise = 0.5 * (np.std(self.X_residual.real) + np.std(self.X_residual.imag))
        self.rmse = np.sqrt(
            np.sum(self.source.residual.real**2 + self.source.residual.imag**2) /
            (2 * len(self.source.residual))
        )
        meaningful_signal = np.where(np.abs(self.parameter.phi) < self.parameter.max_faraday_depth)
        self.signal = np.mean(np.abs(self.X_restored[meaningful_signal]))
        self.peak_signal = np.max(np.abs(self.X_restored))

        self.snr = self.signal / self.res_noise
        self.psnr = self.peak_signal / self.res_noise

        print("Signal-to-noise ratio: {0}".format(self.snr))
        print("Peak Signal-to-noise ratio: {0}".format(self.psnr))
        print("Standard deviation: {0}".format(self.res_noise))

        # self.lags, self.autocorr_res, self.autocorr_res_sq, self.bound, self.percentage_real_in, self.percentage_imag_in, self.percentage_real_in_sq, self.percentage_imag_in_sq = self.source.assess_residuals()

        # self.residual_comparison = self.noiseless_source.data - self.source.model_data
        """
        
        self.fig, self.ax = plt.subplots(nrows=2, ncols=4, sharey='row', figsize=(18, 5))

        # Data
        self.ax[0,0].plot(self.source.lambda2, self.source.data.real, 'k.', label=r"Stokes $Q$")
        self.ax[0,0].plot(self.source.lambda2, self.source.data.imag, 'c.', label=r"Stokes $U$")
        self.ax[0,0].plot(self.source.lambda2, np.abs(self.source.data), 'g.', label=r"$|P|$")
        self.ax[0,0].set_xlabel(r'$\lambda^2$[m$^{2}$]')
        self.ax[0,0].set_ylabel(r'Jy/beam')
        self.ax[0,0].title.set_text("Data")

        self.ax[1,0].plot(self.parameter.phi, self.F_dirty.real, 'c--', label=r"Stokes $Q$")
        self.ax[1,0].plot(self.parameter.phi, self.F_dirty.imag, 'c:', label=r"Stokes $U$")
        self.ax[1,0].plot(self.parameter.phi, np.abs(self.F_dirty), 'k-', label=r"|P|")
        self.ax[1,0].set_xlabel(r'$\phi$[rad m$^{-2}$]')
        self.ax[1,0].set_ylabel(r'Jy/beam m$^2$ rad$^{-1}$ rmtf$^{-1}$')
        self.ax[1,0].set_xlim([-1000,1000])

        # Model
        self.ax[0,1].plot(self.source.lambda2, self.source.model_data.real, 'k.', label=r"Stokes $Q$")
        self.ax[0,1].plot(self.source.lambda2, self.source.model_data.imag, 'c.', label=r"Stokes $U$")
        self.ax[0,1].plot(self.source.lambda2, np.abs(self.source.model_data), 'g.', label=r"$|P|$")
        self.ax[0,1].set_xlabel(r'$\lambda^2$[m$^{2}$]')
        self.ax[0,1].set_ylabel(r'Jy/beam')
        self.ax[0,1].title.set_text("Model")

        self.ax[1,1].get_shared_y_axes().remove(self.ax[1,1])
        self.ax[1,1].clear()
        self.ax[1,1].plot(self.parameter.phi, self.X.data.real, 'c--', label=r"Stokes $Q$")
        self.ax[1,1].plot(self.parameter.phi, self.X.data.imag, 'c:', label=r"Stokes $U$")
        self.ax[1,1].plot(self.parameter.phi, np.abs(self.X.data), 'k-', label=r"$|P|$")
        self.ax[1,1].set_xlabel(r'$\phi$[rad m$^{-2}$]')
        self.ax[1,1].set_ylabel(r'Jy/beam m$^2$ rad$^{-1}$ pix$^{-1}$')
        self.ax[1,1].set_xlim([-1000,1000])
        
        # Residual

        self.ax[0,2].plot(self.source.lambda2, self.source.residual.real, 'k.', label=r"Stokes $Q$")
        self.ax[0,2].plot(self.source.lambda2, self.source.residual.imag, 'c.', label=r"Stokes $U$")
        self.ax[0,2].plot(self.source.lambda2, np.abs(self.source.residual), 'g.', label=r"$|P|$")
        self.ax[0,2].set_xlabel(r'$\lambda^2$[m$^{2}$]')
        self.ax[0,2].set_ylabel(r'Jy/beam')
        self.ax[0,2].title.set_text("Residual")

        self.ax[1,2].plot(self.parameter.phi, self.X_residual.real, 'c--', label=r"Stokes $Q$")
        self.ax[1,2].plot(self.parameter.phi, self.X_residual.imag, 'c:', label=r"Stokes $U$")
        self.ax[1,2].plot(self.parameter.phi, np.abs(self.X_residual), 'k-', label=r"$|P|$")
        self.ax[1,2].set_xlabel(r'$\phi$[rad m$^{-2}$]')
        self.ax[1,2].set_ylabel(r'Jy/beam m$^2$ rad$^{-1}$ rmtf$^{-1}$')
        self.ax[1,2].set_xlim([-1000,1000])
        
        if self.use_wavelet:
            self.ax[0,3].get_shared_y_axes().remove(self.ax[0,3])
            self.ax[0,3].clear()
            self.ax[0,3].plot(self.coeffs)
            self.ax[0,3].title.set_text("Coefficients")

        self.ax[1,3].plot(self.parameter.phi, self.X_restored.real, 'c--', label=r"Stokes $Q$")
        self.ax[1,3].plot(self.parameter.phi, self.X_restored.imag, 'c:', label=r"Stokes $U$")
        self.ax[1,3].plot(self.parameter.phi, np.abs(self.X_restored), 'k-', label=r"$|P|$")
        self.ax[1,3].set_xlim([-1000,1000])
        self.ax[1,3].set_xlabel(r'$\phi$[rad m$^{-2}$]')
        self.ax[1,3].set_ylabel(r'Jy/beam m$^2$ rad$^{-1}$ rmtf$^{-1}$')
        self.ax[1,3].title.set_text("Restored")
        
        self.fig.tight_layout()
        """

# %%
def run_test(
    source_1,
    source_2,
    nsigma,
    remove_frac,
    nu_min=1.008e9,
    nu_max=2.031e9,
    nchannels=1000,
    scenario=1,
    use_wavelet=None,
    append_signal=False
):
    nosigma_objs = []
    for remv_frac in remove_frac:
        nosigma_objs.append(
            Test(
                nu_min=nu_min,
                nu_max=nu_max,
                nchannels=nchannels,
                noise_frac=0.0,
                remove_frac=remv_frac,
                scenario=scenario,
                source_1=source_1,
                source_2=source_2,
                use_wavelet=use_wavelet,
                append_signal=append_signal
            )
        )

    test_objs = []
    for nsig in nsigma:
        for i in range(0, len(remove_frac)):
            copy_object = copy.deepcopy(nosigma_objs[i])
            copy_object.noise_frac = nsig
            copy_object.apply_noise()
            test_objs.append(copy_object)

    del nosigma_objs

    nid = len(nsigma) * len(remove_frac)
    for _id in range(0, nid):
        test_objs[_id].run()

    return test_objs

# %%
# JVLA 1.008 - 2.031 GHz 546 channels
# MeerKAT 0.9 GHz-1.420 GHz 546
# eMERLIN 1.230 - 1.740 GHz 4096
def run_tests(
    source_1,
    source_2,
    nsigma,
    remove_frac,
    nsamples,
    nu_min=1.008e9,
    nu_max=2.031e9,
    nchannels=1000,
    scenario=1,
    use_wavelet=None,
    append_signal=False
):
    m = len(nsigma)
    n = len(remove_frac)
    psnrs = statistics(m, n, nsamples)
    rmses = statistics(m, n, nsamples)
    #noises = statistics(m, n, nsamples)
    sparsities = statistics(m, n, nsamples)
    #ginies = statistics(m, n, nsamples)
    aics = statistics(m, n, nsamples)
    bics = statistics(m, n, nsamples)

    for i in range(0, nsamples):
        test = run_test(
            source_1,
            source_2,
            nsigma,
            remove_frac,
            nu_min=nu_min,
            nu_max=nu_max,
            nchannels=nchannels,
            scenario=scenario,
            use_wavelet=use_wavelet,
            append_signal=append_signal
        )
        psnrs.cumul(list_to2darray([x.psnr for x in test], n, dtype=np.float32))
        #noises.cumul(list_to2darray([x.res_noise for x in test], n, dtype=np.float32))
        sparsities.cumul(list_to2darray([x.sparsity * 100.0 for x in test], n, dtype=np.float32))
        #ginies.cumul(list_to2darray([x.gini for x in test], n, dtype=np.float32))
        rmses.cumul(list_to2darray([x.rmse for x in test], n, dtype=np.float32))
        aics.cumul(list_to2darray([x.aic for x in test], n, dtype=np.float32))
        bics.cumul(list_to2darray([x.bic for x in test], n, dtype=np.float32))
        for t in test:
            del t
        test = []

    psnr_mean, psnr_std = psnrs.mean(), psnrs.std()
    rmse_mean, rmse_std = rmses.mean(), rmses.std()
    #noise_mean, noise_std = noises.mean(), noises.std()
    sparsity_mean, sparsity_std = sparsities.mean(), sparsities.std()
    #gini_mean, gini_std = ginies.mean(), ginies.std()
    aic_mean, aic_std = aics.mean(), aics.std()
    bic_mean, bic_std = bics.mean(), bics.std()
    return psnr_mean, psnr_std, rmse_mean, rmse_std, aic_mean, aic_std, bic_mean, bic_std, sparsity_mean, sparsity_std

# %%
#source_1 = FaradayThinSource(s_nu=0.0035, phi_gal=-200, spectral_idx=1.0)
source_1 = FaradayThinSource(s_nu=0.0035, phi_gal=-400, spectral_idx=0.7)
#source_2 = FaradayThickSource(s_nu=0.0035, phi_fg=140, phi_center=200, spectral_idx=1.0)
source_2 = FaradayThickSource(s_nu=0.0035, phi_fg=95, phi_center=200, spectral_idx=0.7)

# %%
nsigma = [0.2]
remove_frac = [0.3]
scenarios = [1, 2, 3]

# %%
names = ["PSNR", "RMSE", "AIC", "BIC"]
samples = 50
scenarios_means = np.empty((3, len(names)), dtype=np.float32)
scenarios_stds = np.empty((3, len(names)), dtype=np.float32)

append_signal = False

for i in range(len(scenarios)):
    psnr_mean, psnr_std, rmse_mean, rmse_std, aic_mean, aic_std, bic_mean, bic_std, sparsity_mean, sparsity_std = run_tests(
        source_1,
        source_2,
        nsigma,
        remove_frac,
        samples,
        scenario=scenarios[i],
        use_wavelet=None,
        append_signal=append_signal,
        nu_min=0.9e9,
        nu_max=1.67e9
    )
    scenarios_means[i, 0] = psnr_mean
    scenarios_means[i, 1] = rmse_mean
    scenarios_means[i, 2] = aic_mean
    scenarios_means[i, 3] = bic_mean

    scenarios_stds[i, 0] = psnr_std
    scenarios_stds[i, 1] = rmse_std
    scenarios_stds[i, 2] = aic_std
    scenarios_stds[i, 3] = bic_std
# Out:
# FWHM of the main peak of the RMTF: 51.736 rad/m^2
# Maximum recovered width structure: 95.873 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 18081.680
# Signal-to-noise ratio: 1.4522973322343335
# Peak Signal-to-noise ratio: 123.70086562395797
# Standard deviation: 2.6854158932110295e-05
# FWHM of the main peak of the RMTF: 47.344 rad/m^2
# Maximum recovered width structure: 95.694 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16546.611
# Signal-to-noise ratio: 1.444704040195746
# Peak Signal-to-noise ratio: 124.15795674579952
# Standard deviation: 2.7535126719158143e-05
# FWHM of the main peak of the RMTF: 44.360 rad/m^2
# Maximum recovered width structure: 96.141 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15503.835
# Signal-to-noise ratio: 1.439421223749806
# Peak Signal-to-noise ratio: 126.98334783972638
# Standard deviation: 2.6676454581320286e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.4530843744223967
# Peak Signal-to-noise ratio: 136.76367999434166
# Standard deviation: 2.5945439119823277e-05
# FWHM of the main peak of the RMTF: 45.620 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15944.046
# Signal-to-noise ratio: 1.4284913537887576
# Peak Signal-to-noise ratio: 119.26989101961928
# Standard deviation: 2.837596184690483e-05
# FWHM of the main peak of the RMTF: 45.820 rad/m^2
# Maximum recovered width structure: 97.036 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16014.048
# Signal-to-noise ratio: 1.44277993022563
# Peak Signal-to-noise ratio: 120.54409640739023
# Standard deviation: 2.7339159714756534e-05
# FWHM of the main peak of the RMTF: 52.819 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 18460.220
# Signal-to-noise ratio: 1.4437807443209323
# Peak Signal-to-noise ratio: 123.06703506083397
# Standard deviation: 2.623211548780091e-05
# FWHM of the main peak of the RMTF: 45.840 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16021.033
# Signal-to-noise ratio: 1.4353616840593146
# Peak Signal-to-noise ratio: 120.40464405507504
# Standard deviation: 2.8440288588171825e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.450006476762245
# Peak Signal-to-noise ratio: 133.12629740827967
# Standard deviation: 2.5543467927491292e-05
# FWHM of the main peak of the RMTF: 44.641 rad/m^2
# Maximum recovered width structure: 94.716 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15602.025
# Signal-to-noise ratio: 1.449058313897366
# Peak Signal-to-noise ratio: 126.48626425880279
# Standard deviation: 2.6543444619164802e-05
# FWHM of the main peak of the RMTF: 44.605 rad/m^2
# Maximum recovered width structure: 94.894 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15589.562
# Signal-to-noise ratio: 1.4572265318543056
# Peak Signal-to-noise ratio: 134.13061651890982
# Standard deviation: 2.5588673452148214e-05
# FWHM of the main peak of the RMTF: 47.410 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16569.932
# Signal-to-noise ratio: 1.4478976846111977
# Peak Signal-to-noise ratio: 124.55996978060246
# Standard deviation: 2.5408091460121796e-05
# FWHM of the main peak of the RMTF: 44.699 rad/m^2
# Maximum recovered width structure: 95.516 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15622.229
# Signal-to-noise ratio: 1.4501368980760692
# Peak Signal-to-noise ratio: 126.07020977960751
# Standard deviation: 2.6748308300739154e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.4537809192474005
# Peak Signal-to-noise ratio: 129.67483827608442
# Standard deviation: 2.6824851374840364e-05
# FWHM of the main peak of the RMTF: 48.099 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16810.644
# Signal-to-noise ratio: 1.4557526880969938
# Peak Signal-to-noise ratio: 128.0588085527058
# Standard deviation: 2.5924513465724885e-05
# FWHM of the main peak of the RMTF: 46.575 rad/m^2
# Maximum recovered width structure: 94.008 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16277.843
# Signal-to-noise ratio: 1.4433799479533052
# Peak Signal-to-noise ratio: 125.03970523171122
# Standard deviation: 2.6586101739667356e-05
# FWHM of the main peak of the RMTF: 44.223 rad/m^2
# Maximum recovered width structure: 96.857 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15456.008
# Signal-to-noise ratio: 1.4504473194209062
# Peak Signal-to-noise ratio: 132.97444938876012
# Standard deviation: 2.61803998000687e-05
# FWHM of the main peak of the RMTF: 49.860 rad/m^2
# Maximum recovered width structure: 96.498 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 17426.136
# Signal-to-noise ratio: 1.4530390147345453
# Peak Signal-to-noise ratio: 125.89158020779507
# Standard deviation: 2.7508856874192134e-05
# FWHM of the main peak of the RMTF: 44.206 rad/m^2
# Maximum recovered width structure: 96.947 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15450.088
# Signal-to-noise ratio: 1.4691607779879299
# Peak Signal-to-noise ratio: 136.79733677451043
# Standard deviation: 2.5395102056791075e-05
# FWHM of the main peak of the RMTF: 44.988 rad/m^2
# Maximum recovered width structure: 93.038 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15723.220
# Signal-to-noise ratio: 1.441628185239985
# Peak Signal-to-noise ratio: 121.05995472034321
# Standard deviation: 2.6532683477853425e-05
# FWHM of the main peak of the RMTF: 50.587 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 17680.070
# Signal-to-noise ratio: 1.4506668908303917
# Peak Signal-to-noise ratio: 120.4558169180325
# Standard deviation: 2.696847150218673e-05
# FWHM of the main peak of the RMTF: 44.206 rad/m^2
# Maximum recovered width structure: 96.947 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15450.088
# Signal-to-noise ratio: 1.4406359653899605
# Peak Signal-to-noise ratio: 127.18609605971204
# Standard deviation: 2.6917421564576216e-05
# FWHM of the main peak of the RMTF: 47.273 rad/m^2
# Maximum recovered width structure: 94.982 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16521.833
# Signal-to-noise ratio: 1.44553899901318
# Peak Signal-to-noise ratio: 124.27155765768678
# Standard deviation: 2.7043335649068467e-05
# FWHM of the main peak of the RMTF: 44.482 rad/m^2
# Maximum recovered width structure: 95.516 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15546.370
# Signal-to-noise ratio: 1.45046144510106
# Peak Signal-to-noise ratio: 134.77421503934073
# Standard deviation: 2.4869395929272287e-05
# FWHM of the main peak of the RMTF: 44.623 rad/m^2
# Maximum recovered width structure: 94.805 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15595.786
# Signal-to-noise ratio: 1.4594910454749301
# Peak Signal-to-noise ratio: 131.32366755171336
# Standard deviation: 2.5753555746632628e-05
# FWHM of the main peak of the RMTF: 45.950 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16059.659
# Signal-to-noise ratio: 1.445202479743288
# Peak Signal-to-noise ratio: 124.76931759697902
# Standard deviation: 2.6344569050706923e-05
# FWHM of the main peak of the RMTF: 47.297 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16530.137
# Signal-to-noise ratio: 1.4412588708319318
# Peak Signal-to-noise ratio: 126.03451621734682
# Standard deviation: 2.69772281171754e-05
# FWHM of the main peak of the RMTF: 44.917 rad/m^2
# Maximum recovered width structure: 95.516 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15698.438
# Signal-to-noise ratio: 1.4489837121867961
# Peak Signal-to-noise ratio: 116.58241279399755
# Standard deviation: 2.808850331348367e-05
# FWHM of the main peak of the RMTF: 44.692 rad/m^2
# Maximum recovered width structure: 97.216 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15619.910
# Signal-to-noise ratio: 1.4423000090501064
# Peak Signal-to-noise ratio: 127.41196596411947
# Standard deviation: 2.591816519270651e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.447167266941431
# Peak Signal-to-noise ratio: 131.00974389595012
# Standard deviation: 2.471194602549076e-05
# FWHM of the main peak of the RMTF: 45.728 rad/m^2
# Maximum recovered width structure: 89.728 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15981.802
# Signal-to-noise ratio: 1.4486137808893313
# Peak Signal-to-noise ratio: 129.02974598328169
# Standard deviation: 2.6599940611049533e-05
# FWHM of the main peak of the RMTF: 44.641 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15601.909
# Signal-to-noise ratio: 1.4383334315301817
# Peak Signal-to-noise ratio: 122.28242903884367
# Standard deviation: 2.6025001716334373e-05
# FWHM of the main peak of the RMTF: 44.139 rad/m^2
# Maximum recovered width structure: 97.306 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15426.533
# Signal-to-noise ratio: 1.4605683497265072
# Peak Signal-to-noise ratio: 134.2900415949525
# Standard deviation: 2.5636265490902588e-05
# FWHM of the main peak of the RMTF: 53.609 rad/m^2
# Maximum recovered width structure: 97.396 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 18736.404
# Signal-to-noise ratio: 1.4687217815531637
# Peak Signal-to-noise ratio: 132.70180385891376
# Standard deviation: 2.571374352555722e-05
# FWHM of the main peak of the RMTF: 44.482 rad/m^2
# Maximum recovered width structure: 95.516 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15546.370
# Signal-to-noise ratio: 1.4429856725358607
# Peak Signal-to-noise ratio: 123.75339514593297
# Standard deviation: 2.7534482796909288e-05
# FWHM of the main peak of the RMTF: 47.297 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16530.137
# Signal-to-noise ratio: 1.4622404520378292
# Peak Signal-to-noise ratio: 121.6527148279728
# Standard deviation: 2.734830923145637e-05
# FWHM of the main peak of the RMTF: 47.773 rad/m^2
# Maximum recovered width structure: 97.396 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16696.723
# Signal-to-noise ratio: 1.4589949385203898
# Peak Signal-to-noise ratio: 127.28041858793027
# Standard deviation: 2.7011190468329005e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.4537159552691927
# Peak Signal-to-noise ratio: 132.5415278771965
# Standard deviation: 2.555693208705634e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.4307822912805919
# Peak Signal-to-noise ratio: 126.89270933014171
# Standard deviation: 2.5706955057103187e-05
# FWHM of the main peak of the RMTF: 47.602 rad/m^2
# Maximum recovered width structure: 97.126 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16637.054
# Signal-to-noise ratio: 1.4554761236062703
# Peak Signal-to-noise ratio: 124.84699428812112
# Standard deviation: 2.6259320293320343e-05
# FWHM of the main peak of the RMTF: 46.222 rad/m^2
# Maximum recovered width structure: 93.038 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16154.588
# Signal-to-noise ratio: 1.4426119225955951
# Peak Signal-to-noise ratio: 120.50110378128004
# Standard deviation: 2.7316664272802882e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.439739003615023
# Peak Signal-to-noise ratio: 126.78826819362162
# Standard deviation: 2.622607644298114e-05
# FWHM of the main peak of the RMTF: 47.229 rad/m^2
# Maximum recovered width structure: 93.655 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16506.476
# Signal-to-noise ratio: 1.46117983777348
# Peak Signal-to-noise ratio: 129.92353885299178
# Standard deviation: 2.6518995582591742e-05
# FWHM of the main peak of the RMTF: 47.284 rad/m^2
# Maximum recovered width structure: 95.962 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16525.930
# Signal-to-noise ratio: 1.4607168470433265
# Peak Signal-to-noise ratio: 129.76693881301384
# Standard deviation: 2.6148929464397952e-05
# FWHM of the main peak of the RMTF: 46.097 rad/m^2
# Maximum recovered width structure: 95.694 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16110.801
# Signal-to-noise ratio: 1.4400017960579585
# Peak Signal-to-noise ratio: 120.04596243829374
# Standard deviation: 2.8329606720944867e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.4614471372846192
# Peak Signal-to-noise ratio: 135.69044980378035
# Standard deviation: 2.489990583853796e-05
# FWHM of the main peak of the RMTF: 50.708 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 17722.547
# Signal-to-noise ratio: 1.4600579383852204
# Peak Signal-to-noise ratio: 128.65983736029207
# Standard deviation: 2.476514782756567e-05
# FWHM of the main peak of the RMTF: 46.731 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16332.528
# Signal-to-noise ratio: 1.4466100842105425
# Peak Signal-to-noise ratio: 128.31347520766658
# Standard deviation: 2.616735582705587e-05
# FWHM of the main peak of the RMTF: 46.172 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16137.175
# Signal-to-noise ratio: 1.456543400337781
# Peak Signal-to-noise ratio: 125.62505041096826
# Standard deviation: 2.6978077585226856e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.4506379388480666
# Peak Signal-to-noise ratio: 133.59798406605356
# Standard deviation: 2.6177131076110527e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.4341936896295227
# Peak Signal-to-noise ratio: 59.26316822387053
# Standard deviation: 2.7662004868034273e-05
# FWHM of the main peak of the RMTF: 48.399 rad/m^2
# Maximum recovered width structure: 92.687 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16915.473
# Signal-to-noise ratio: 1.4641406873714977
# Peak Signal-to-noise ratio: 69.94337648858735
# Standard deviation: 2.6074378183693625e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.4392720081075059
# Peak Signal-to-noise ratio: 65.15298135386239
# Standard deviation: 2.6490813979762606e-05
# FWHM of the main peak of the RMTF: 46.794 rad/m^2
# Maximum recovered width structure: 91.550 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16354.629
# Signal-to-noise ratio: 1.469312615149991
# Peak Signal-to-noise ratio: 69.16100606308997
# Standard deviation: 2.6244284526910633e-05
# FWHM of the main peak of the RMTF: 44.965 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15715.178
# Signal-to-noise ratio: 1.419415548904495
# Peak Signal-to-noise ratio: 58.66259564665217
# Standard deviation: 2.7711284928955138e-05
# FWHM of the main peak of the RMTF: 44.588 rad/m^2
# Maximum recovered width structure: 94.982 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15583.351
# Signal-to-noise ratio: 1.4332636657442523
# Peak Signal-to-noise ratio: 60.58167638752014
# Standard deviation: 2.8010854293825105e-05
# FWHM of the main peak of the RMTF: 44.499 rad/m^2
# Maximum recovered width structure: 95.427 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15552.500
# Signal-to-noise ratio: 1.4453370474376785
# Peak Signal-to-noise ratio: 62.39302528918164
# Standard deviation: 2.6899502699961886e-05
# FWHM of the main peak of the RMTF: 45.081 rad/m^2
# Maximum recovered width structure: 92.599 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15755.979
# Signal-to-noise ratio: 1.450914828859479
# Peak Signal-to-noise ratio: 64.90161770839413
# Standard deviation: 2.6643298042472452e-05
# FWHM of the main peak of the RMTF: 47.281 rad/m^2
# Maximum recovered width structure: 96.498 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16524.857
# Signal-to-noise ratio: 1.4645733129004483
# Peak Signal-to-noise ratio: 70.03634101176887
# Standard deviation: 2.45764349529054e-05
# FWHM of the main peak of the RMTF: 45.291 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15829.221
# Signal-to-noise ratio: 1.4246006346924698
# Peak Signal-to-noise ratio: 61.2647001556441
# Standard deviation: 2.6116329536307603e-05
# FWHM of the main peak of the RMTF: 52.189 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 18240.163
# Signal-to-noise ratio: 1.4565608034947446
# Peak Signal-to-noise ratio: 73.72211216631675
# Standard deviation: 2.5396288037882186e-05
# FWHM of the main peak of the RMTF: 44.122 rad/m^2
# Maximum recovered width structure: 97.396 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15420.676
# Signal-to-noise ratio: 1.4487482711282
# Peak Signal-to-noise ratio: 63.00782025604942
# Standard deviation: 2.7361233151168562e-05
# FWHM of the main peak of the RMTF: 45.025 rad/m^2
# Maximum recovered width structure: 92.863 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15736.280
# Signal-to-noise ratio: 1.4559423843961508
# Peak Signal-to-noise ratio: 66.87648899504605
# Standard deviation: 2.5570518118911423e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.4475825390091968
# Peak Signal-to-noise ratio: 62.45850555603556
# Standard deviation: 2.747742473729886e-05
# FWHM of the main peak of the RMTF: 45.303 rad/m^2
# Maximum recovered width structure: 96.319 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15833.499
# Signal-to-noise ratio: 1.4496490361628227
# Peak Signal-to-noise ratio: 63.768994862202725
# Standard deviation: 2.6373938453616574e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.4696748304355058
# Peak Signal-to-noise ratio: 64.33213405796104
# Standard deviation: 2.6544825232122093e-05
# FWHM of the main peak of the RMTF: 45.730 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15982.495
# Signal-to-noise ratio: 1.438735760305081
# Peak Signal-to-noise ratio: 61.13436256093258
# Standard deviation: 2.7733767637982965e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.4595070778863959
# Peak Signal-to-noise ratio: 63.74394382415589
# Standard deviation: 2.687767118914053e-05
# FWHM of the main peak of the RMTF: 44.426 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15526.824
# Signal-to-noise ratio: 1.4384524298894468
# Peak Signal-to-noise ratio: 59.72849207183196
# Standard deviation: 2.838434375007637e-05
# FWHM of the main peak of the RMTF: 44.240 rad/m^2
# Maximum recovered width structure: 96.767 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15461.941
# Signal-to-noise ratio: 1.4317624755980656
# Peak Signal-to-noise ratio: 61.62864512071878
# Standard deviation: 2.6082949261763133e-05
# FWHM of the main peak of the RMTF: 45.614 rad/m^2
# Maximum recovered width structure: 95.873 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15942.234
# Signal-to-noise ratio: 1.4474962107183325
# Peak Signal-to-noise ratio: 66.0337398148836
# Standard deviation: 2.6023582904599607e-05
# FWHM of the main peak of the RMTF: 48.291 rad/m^2
# Maximum recovered width structure: 92.161 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16877.794
# Signal-to-noise ratio: 1.4642021899659388
# Peak Signal-to-noise ratio: 71.66540013471018
# Standard deviation: 2.6648587663657963e-05
# FWHM of the main peak of the RMTF: 45.196 rad/m^2
# Maximum recovered width structure: 96.857 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15796.112
# Signal-to-noise ratio: 1.447491313075357
# Peak Signal-to-noise ratio: 63.351186242369685
# Standard deviation: 2.721191049204208e-05
# FWHM of the main peak of the RMTF: 45.896 rad/m^2
# Maximum recovered width structure: 89.987 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16040.521
# Signal-to-noise ratio: 1.4606570144363804
# Peak Signal-to-noise ratio: 68.4670308813766
# Standard deviation: 2.6131991035072133e-05
# FWHM of the main peak of the RMTF: 46.232 rad/m^2
# Maximum recovered width structure: 91.986 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16158.165
# Signal-to-noise ratio: 1.461385409184511
# Peak Signal-to-noise ratio: 65.35467004910684
# Standard deviation: 2.7346910428605042e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.463127021294079
# Peak Signal-to-noise ratio: 66.49757494008752
# Standard deviation: 2.553913691372145e-05
# FWHM of the main peak of the RMTF: 47.183 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16490.433
# Signal-to-noise ratio: 1.4414881674930853
# Peak Signal-to-noise ratio: 63.45525943038331
# Standard deviation: 2.5877770895021968e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.4549099440425706
# Peak Signal-to-noise ratio: 63.73947694779089
# Standard deviation: 2.6348723622504622e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.4406457264760502
# Peak Signal-to-noise ratio: 61.34117772798411
# Standard deviation: 2.785885772027541e-05
# FWHM of the main peak of the RMTF: 47.193 rad/m^2
# Maximum recovered width structure: 95.338 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16494.062
# Signal-to-noise ratio: 1.4471044779462732
# Peak Signal-to-noise ratio: 64.19017901211568
# Standard deviation: 2.634192060213536e-05
# FWHM of the main peak of the RMTF: 49.150 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 17178.046
# Signal-to-noise ratio: 1.4371802721791502
# Peak Signal-to-noise ratio: 65.51267797505045
# Standard deviation: 2.605891859275289e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.4332837038846529
# Peak Signal-to-noise ratio: 61.984070250605306
# Standard deviation: 2.6248482754454017e-05
# FWHM of the main peak of the RMTF: 47.295 rad/m^2
# Maximum recovered width structure: 89.038 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16529.759
# Signal-to-noise ratio: 1.4588369364458271
# Peak Signal-to-noise ratio: 69.47205570248953
# Standard deviation: 2.6498815714148805e-05
# FWHM of the main peak of the RMTF: 46.432 rad/m^2
# Maximum recovered width structure: 96.230 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16228.137
# Signal-to-noise ratio: 1.4532084557627554
# Peak Signal-to-noise ratio: 66.12639205011543
# Standard deviation: 2.6885682018473744e-05
# FWHM of the main peak of the RMTF: 44.257 rad/m^2
# Maximum recovered width structure: 96.678 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15467.887
# Signal-to-noise ratio: 1.4544281488551847
# Peak Signal-to-noise ratio: 62.00824129910064
# Standard deviation: 2.6881798476097174e-05
# FWHM of the main peak of the RMTF: 49.983 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 17469.178
# Signal-to-noise ratio: 1.4249302587120836
# Peak Signal-to-noise ratio: 67.56365036843788
# Standard deviation: 2.6688996513257734e-05
# FWHM of the main peak of the RMTF: 46.193 rad/m^2
# Maximum recovered width structure: 94.716 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16144.396
# Signal-to-noise ratio: 1.4586003761638116
# Peak Signal-to-noise ratio: 67.1956305908473
# Standard deviation: 2.6435242034494877e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.438457889538884
# Peak Signal-to-noise ratio: 61.670123461600845
# Standard deviation: 2.6709756639320403e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.4584530543458314
# Peak Signal-to-noise ratio: 66.18976689474654
# Standard deviation: 2.583376772236079e-05
# FWHM of the main peak of the RMTF: 46.619 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16293.278
# Signal-to-noise ratio: 1.4443450964600313
# Peak Signal-to-noise ratio: 63.70562175160066
# Standard deviation: 2.6611018256517127e-05
# FWHM of the main peak of the RMTF: 44.336 rad/m^2
# Maximum recovered width structure: 97.396 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15495.310
# Signal-to-noise ratio: 1.4519372857899793
# Peak Signal-to-noise ratio: 64.38719638527489
# Standard deviation: 2.5865869247354567e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.424385719127045
# Peak Signal-to-noise ratio: 54.462762897727806
# Standard deviation: 3.0131397579680197e-05
# FWHM of the main peak of the RMTF: 45.100 rad/m^2
# Maximum recovered width structure: 92.512 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15762.575
# Signal-to-noise ratio: 1.4524720002764457
# Peak Signal-to-noise ratio: 66.26476867214139
# Standard deviation: 2.66540955635719e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.4293204147825924
# Peak Signal-to-noise ratio: 58.8533333252138
# Standard deviation: 2.7388347007217817e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.4211110610261217
# Peak Signal-to-noise ratio: 59.046472518421346
# Standard deviation: 2.602989479782991e-05
# FWHM of the main peak of the RMTF: 45.229 rad/m^2
# Maximum recovered width structure: 92.950 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15807.406
# Signal-to-noise ratio: 1.436373752648463
# Peak Signal-to-noise ratio: 63.2013543943703
# Standard deviation: 2.6189833079115488e-05
# FWHM of the main peak of the RMTF: 50.345 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 17595.416
# Signal-to-noise ratio: 1.4663249769791429
# Peak Signal-to-noise ratio: 70.08356582406958
# Standard deviation: 2.6594210794428363e-05
# FWHM of the main peak of the RMTF: 44.464 rad/m^2
# Maximum recovered width structure: 95.605 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15540.254
# Signal-to-noise ratio: 1.4674049710978363
# Peak Signal-to-noise ratio: 68.73463290230626
# Standard deviation: 2.5953126169042662e-05
# FWHM of the main peak of the RMTF: 45.523 rad/m^2
# Maximum recovered width structure: 96.319 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15910.395
# Signal-to-noise ratio: 1.4412217572510861
# Peak Signal-to-noise ratio: 63.45872064821316
# Standard deviation: 2.6946452635456808e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.4337618317633787
# Peak Signal-to-noise ratio: 62.813522930359696
# Standard deviation: 2.6275876734871417e-05
# FWHM of the main peak of the RMTF: 45.182 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15791.120
# Signal-to-noise ratio: 1.6237092987143829
# Peak Signal-to-noise ratio: 122.60929218630271
# Standard deviation: 2.756075991783291e-05
# FWHM of the main peak of the RMTF: 46.061 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16098.373
# Signal-to-noise ratio: 1.6479119545867973
# Peak Signal-to-noise ratio: 129.93608033433455
# Standard deviation: 2.6113972126040608e-05
# FWHM of the main peak of the RMTF: 50.366 rad/m^2
# Maximum recovered width structure: 97.396 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 17603.032
# Signal-to-noise ratio: 1.593558397135683
# Peak Signal-to-noise ratio: 119.43013308024724
# Standard deviation: 2.6506721042096615e-05
# FWHM of the main peak of the RMTF: 44.291 rad/m^2
# Maximum recovered width structure: 96.498 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15479.818
# Signal-to-noise ratio: 1.6588419466266369
# Peak Signal-to-noise ratio: 133.66597110513013
# Standard deviation: 2.5028759409906343e-05
# FWHM of the main peak of the RMTF: 44.240 rad/m^2
# Maximum recovered width structure: 96.767 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15461.941
# Signal-to-noise ratio: 1.629414103623129
# Peak Signal-to-noise ratio: 127.5514481134774
# Standard deviation: 2.661956568772439e-05
# FWHM of the main peak of the RMTF: 48.564 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16972.986
# Signal-to-noise ratio: 1.650663743107759
# Peak Signal-to-noise ratio: 134.1968893740541
# Standard deviation: 2.587525887065567e-05
# FWHM of the main peak of the RMTF: 44.641 rad/m^2
# Maximum recovered width structure: 94.716 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15602.025
# Signal-to-noise ratio: 1.5996819403335139
# Peak Signal-to-noise ratio: 121.3384609385432
# Standard deviation: 2.7138206860399805e-05
# FWHM of the main peak of the RMTF: 52.056 rad/m^2
# Maximum recovered width structure: 97.036 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 18193.584
# Signal-to-noise ratio: 1.6323837595534654
# Peak Signal-to-noise ratio: 122.4174994048699
# Standard deviation: 2.6449240976944566e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.626320527938588
# Peak Signal-to-noise ratio: 131.7367530889992
# Standard deviation: 2.6404086383990943e-05
# FWHM of the main peak of the RMTF: 44.172 rad/m^2
# Maximum recovered width structure: 97.126 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15438.285
# Signal-to-noise ratio: 1.6079032667905984
# Peak Signal-to-noise ratio: 123.11951761135371
# Standard deviation: 2.7333238904247992e-05
# FWHM of the main peak of the RMTF: 45.235 rad/m^2
# Maximum recovered width structure: 97.216 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15809.560
# Signal-to-noise ratio: 1.6608188710526222
# Peak Signal-to-noise ratio: 134.8411673156526
# Standard deviation: 2.627634967211634e-05
# FWHM of the main peak of the RMTF: 44.641 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15601.909
# Signal-to-noise ratio: 1.6042210296968045
# Peak Signal-to-noise ratio: 121.57411976004113
# Standard deviation: 2.658826815604698e-05
# FWHM of the main peak of the RMTF: 52.776 rad/m^2
# Maximum recovered width structure: 96.230 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 18445.296
# Signal-to-noise ratio: 1.6406479981085098
# Peak Signal-to-noise ratio: 129.75410091660328
# Standard deviation: 2.583211607998237e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.6549134983149527
# Peak Signal-to-noise ratio: 132.88310430247574
# Standard deviation: 2.663640771061182e-05
# FWHM of the main peak of the RMTF: 48.680 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 17013.808
# Signal-to-noise ratio: 1.6295691064810673
# Peak Signal-to-noise ratio: 122.92773195856462
# Standard deviation: 2.717207644309383e-05
# FWHM of the main peak of the RMTF: 46.101 rad/m^2
# Maximum recovered width structure: 88.181 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16112.468
# Signal-to-noise ratio: 1.623531511431467
# Peak Signal-to-noise ratio: 119.90513015685616
# Standard deviation: 2.7468737243907526e-05
# FWHM of the main peak of the RMTF: 47.249 rad/m^2
# Maximum recovered width structure: 90.160 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16513.493
# Signal-to-noise ratio: 1.641605429234508
# Peak Signal-to-noise ratio: 125.20318318251144
# Standard deviation: 2.6830090064322576e-05
# FWHM of the main peak of the RMTF: 45.073 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15753.106
# Signal-to-noise ratio: 1.6513318191957813
# Peak Signal-to-noise ratio: 131.45392035575776
# Standard deviation: 2.6123354473384097e-05
# FWHM of the main peak of the RMTF: 46.283 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16176.067
# Signal-to-noise ratio: 1.6365075247897176
# Peak Signal-to-noise ratio: 124.31770675324769
# Standard deviation: 2.7291242076898925e-05
# FWHM of the main peak of the RMTF: 45.389 rad/m^2
# Maximum recovered width structure: 91.201 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15863.335
# Signal-to-noise ratio: 1.67259638534122
# Peak Signal-to-noise ratio: 139.0730647111778
# Standard deviation: 2.6030593289760873e-05
# FWHM of the main peak of the RMTF: 50.103 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 17511.159
# Signal-to-noise ratio: 1.647955773262638
# Peak Signal-to-noise ratio: 129.94721610280018
# Standard deviation: 2.590351869002916e-05
# FWHM of the main peak of the RMTF: 44.877 rad/m^2
# Maximum recovered width structure: 93.567 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15684.392
# Signal-to-noise ratio: 1.6324645148877988
# Peak Signal-to-noise ratio: 120.72097929201544
# Standard deviation: 2.622879037517123e-05
# FWHM of the main peak of the RMTF: 45.510 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15905.683
# Signal-to-noise ratio: 1.6393541248685386
# Peak Signal-to-noise ratio: 129.07453564569244
# Standard deviation: 2.738908733590506e-05
# FWHM of the main peak of the RMTF: 51.600 rad/m^2
# Maximum recovered width structure: 93.126 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 18034.036
# Signal-to-noise ratio: 1.6711317752800612
# Peak Signal-to-noise ratio: 132.3649078168404
# Standard deviation: 2.556220169935841e-05
# FWHM of the main peak of the RMTF: 46.395 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16215.048
# Signal-to-noise ratio: 1.661655160960333
# Peak Signal-to-noise ratio: 131.8437076187822
# Standard deviation: 2.601633605081588e-05
# FWHM of the main peak of the RMTF: 48.680 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 17013.808
# Signal-to-noise ratio: 1.6438365226984804
# Peak Signal-to-noise ratio: 126.7538510563224
# Standard deviation: 2.6825753593584523e-05
# FWHM of the main peak of the RMTF: 44.534 rad/m^2
# Maximum recovered width structure: 95.249 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15564.800
# Signal-to-noise ratio: 1.6414192930503482
# Peak Signal-to-noise ratio: 126.96866026381717
# Standard deviation: 2.670936009963043e-05
# FWHM of the main peak of the RMTF: 46.283 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16176.067
# Signal-to-noise ratio: 1.6374992872582184
# Peak Signal-to-noise ratio: 124.38254849821101
# Standard deviation: 2.6483256078790873e-05
# FWHM of the main peak of the RMTF: 44.641 rad/m^2
# Maximum recovered width structure: 94.716 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15602.025
# Signal-to-noise ratio: 1.6465152781208947
# Peak Signal-to-noise ratio: 128.83153960599194
# Standard deviation: 2.6471760065760463e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.636614368940829
# Peak Signal-to-noise ratio: 130.49231536344993
# Standard deviation: 2.737337490543723e-05
# FWHM of the main peak of the RMTF: 44.840 rad/m^2
# Maximum recovered width structure: 93.743 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15671.565
# Signal-to-noise ratio: 1.6420024569911553
# Peak Signal-to-noise ratio: 122.30018028466402
# Standard deviation: 2.655213393154554e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.65429804618471
# Peak Signal-to-noise ratio: 134.0454983717176
# Standard deviation: 2.6022145902970806e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.6554004826027071
# Peak Signal-to-noise ratio: 129.4027056025531
# Standard deviation: 2.663979284989182e-05
# FWHM of the main peak of the RMTF: 45.330 rad/m^2
# Maximum recovered width structure: 91.463 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15842.907
# Signal-to-noise ratio: 1.6405910846059335
# Peak Signal-to-noise ratio: 126.40721326585962
# Standard deviation: 2.661344115040265e-05
# FWHM of the main peak of the RMTF: 44.172 rad/m^2
# Maximum recovered width structure: 97.126 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15438.285
# Signal-to-noise ratio: 1.6371878938584636
# Peak Signal-to-noise ratio: 129.3910678799433
# Standard deviation: 2.6654604880604893e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.6197104135293765
# Peak Signal-to-noise ratio: 122.74116484243923
# Standard deviation: 2.729754487518221e-05
# FWHM of the main peak of the RMTF: 44.426 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15526.824
# Signal-to-noise ratio: 1.6286555879849456
# Peak Signal-to-noise ratio: 127.37623948853054
# Standard deviation: 2.651272006914951e-05
# FWHM of the main peak of the RMTF: 47.639 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16649.799
# Signal-to-noise ratio: 1.6475099953128514
# Peak Signal-to-noise ratio: 127.42458038981043
# Standard deviation: 2.6409252313897014e-05
# FWHM of the main peak of the RMTF: 44.172 rad/m^2
# Maximum recovered width structure: 97.126 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15438.285
# Signal-to-noise ratio: 1.6039190324307993
# Peak Signal-to-noise ratio: 120.11580593170788
# Standard deviation: 2.7381172913010232e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.6430385311201372
# Peak Signal-to-noise ratio: 125.58254764884451
# Standard deviation: 2.6583624276099727e-05
# FWHM of the main peak of the RMTF: 46.665 rad/m^2
# Maximum recovered width structure: 92.599 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16309.297
# Signal-to-noise ratio: 1.6233561153912053
# Peak Signal-to-noise ratio: 127.52771689016667
# Standard deviation: 2.6475736376596615e-05
# FWHM of the main peak of the RMTF: 56.218 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 19648.038
# Signal-to-noise ratio: 1.6565890511446257
# Peak Signal-to-noise ratio: 134.78549271331926
# Standard deviation: 2.5440727768000215e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.6268421250251064
# Peak Signal-to-noise ratio: 124.47611037698009
# Standard deviation: 2.7626665541902184e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.614411116054365
# Peak Signal-to-noise ratio: 124.34196523236328
# Standard deviation: 2.7185673388885334e-05
# FWHM of the main peak of the RMTF: 44.965 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15715.178
# Signal-to-noise ratio: 1.6097610614977942
# Peak Signal-to-noise ratio: 119.56079345894925
# Standard deviation: 2.7472662623040378e-05
# FWHM of the main peak of the RMTF: 46.942 rad/m^2
# Maximum recovered width structure: 95.962 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16406.261
# Signal-to-noise ratio: 1.6350867142659418
# Peak Signal-to-noise ratio: 131.99084883511483
# Standard deviation: 2.6064073608722538e-05
# FWHM of the main peak of the RMTF: 47.551 rad/m^2
# Maximum recovered width structure: 92.775 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16619.230
# Signal-to-noise ratio: 1.6644617967938327
# Peak Signal-to-noise ratio: 122.27235451868641
# Standard deviation: 2.6354609872214496e-05
# FWHM of the main peak of the RMTF: 47.907 rad/m^2
# Maximum recovered width structure: 93.743 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 16743.550
# Signal-to-noise ratio: 1.6446030949070332
# Peak Signal-to-noise ratio: 127.18347578810479
# Standard deviation: 2.6929159503197297e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.6544610410487346
# Peak Signal-to-noise ratio: 133.0491439311242
# Standard deviation: 2.630052767926827e-05
# FWHM of the main peak of the RMTF: 44.105 rad/m^2
# Maximum recovered width structure: 97.486 rad/m^2
# Maximum Faraday Depth to which one has more than 50% sensitivity: 15414.831
# Signal-to-noise ratio: 1.6177090012241053
# Peak Signal-to-noise ratio: 126.07300074147099
# Standard deviation: 2.5806919438764453e-05

# %%
radiotelescope = "meerkat"
np.save("deltaf_" + radiotelescope + "_scenarios_means.npy", scenarios_means)
np.save("deltaf_" + radiotelescope + "_scenarios_stds.npy", scenarios_stds)

# %%
print(
    "Scenario 1: Best AIC Delta function basis : {0:.2f} \pm {1:.2f}".format(
        scenarios_means[0, 2], scenarios_stds[0, 2]
    )
)
print(
    "Scenario 2: Best AIC Delta function basis : {0:.2f} \pm {1:.2f}".format(
        scenarios_means[1, 2], scenarios_stds[1, 2]
    )
)
print(
    "Scenario 3: Best AIC Delta function basis : {0:.2f} \pm {1:.2f}".format(
        scenarios_means[2, 2], scenarios_stds[2, 2]
    )
)
# Out:
# Scenario 1: Best AIC Delta function basis : -20237.86 \pm 70.09
# Scenario 2: Best AIC Delta function basis : -20183.10 \pm 66.40
# Scenario 3: Best AIC Delta function basis : -20161.74 \pm 74.68

# %%
print(
    "Scenario 1: Best BIC Delta function basis : {0:.2f} \pm {1:.2f}".format(
        scenarios_means[0, 3], scenarios_stds[0, 3]
    )
)
print(
    "Scenario 2: Best BIC Delta function basis : {0:.2f} \pm {1:.2f}".format(
        scenarios_means[1, 3], scenarios_stds[1, 3]
    )
)
print(
    "Scenario 3: Best BIC Delta function basis : {0:.2f} \pm {1:.2f}".format(
        scenarios_means[2, 3], scenarios_stds[2, 3]
    )
)
# Out:
# Scenario 1: Best BIC Delta function basis : -20012.46 \pm 150.53
# Scenario 2: Best BIC Delta function basis : -19859.63 \pm 151.46
# Scenario 3: Best BIC Delta function basis : -19810.37 \pm 165.54

# %%
print(
    "Scenario 1: Best PSNR Delta function basis : {0:.2f} \pm {1:.2f}".format(
        scenarios_means[0, 0], scenarios_stds[0, 0]
    )
)
print(
    "Scenario 2: Best PSNR Delta function basis : {0:.2f} \pm {1:.2f}".format(
        scenarios_means[1, 0], scenarios_stds[1, 0]
    )
)
print(
    "Scenario 3: Best PSNR Delta function basis : {0:.2f} \pm {1:.2f}".format(
        scenarios_means[2, 0], scenarios_stds[2, 0]
    )
)
# Out:
# Scenario 1: Best PSNR Delta function basis : 127.14 \pm 4.96
# Scenario 2: Best PSNR Delta function basis : 64.37 \pm 3.72
# Scenario 3: Best PSNR Delta function basis : 127.31 \pm 4.77

# %%
print(
    "Scenario 1: Best RMSE Delta function basis : {0:.2f} \pm {1:.2f}".format(
        scenarios_means[0, 1] * 10**5, scenarios_stds[0, 1] * 10**5
    )
)
print(
    "Scenario 2: Best RMSE Delta function basis : {0:.2f} \pm {1:.2f}".format(
        scenarios_means[1, 1] * 10**5, scenarios_stds[1, 1] * 10**5
    )
)
print(
    "Scenario 3: Best RMSE Delta function basis : {0:.2f} \pm {1:.2f}".format(
        scenarios_means[2, 1] * 10**5, scenarios_stds[2, 1] * 10**5
    )
)
# Out:
# Scenario 1: Best RMSE Delta function basis : 70.43 \pm 1.32
# Scenario 2: Best RMSE Delta function basis : 70.87 \pm 1.65
# Scenario 3: Best RMSE Delta function basis : 71.14 \pm 1.49
